# %% [markdown]
# ## Visualisation d’un nuage de points et exploration des variables
# Pour cette partie, nous allons utiliser le dataset suivante : house_pricing.csv que vous pouvez
# trouver dans le dossier Data Sources. Nous allons tenter de comprendre un peu mieux ce
# dataset par la visualisation

# %% [markdown]
# #### 1) Importez les librairies qu’il nous faut (pandas, seaborn, matplotlib, numpy)

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #### 2) Donnez la liste des variables présentes dans ce dataset ainsi que leur nature (sont elles qualitatives, quantitatives, discrète etc...) et leur type (float, int, str etc...)
# \- Une variable est dite __quantitative__ si elle est représentée par un nombre. \
# *Un âge, une distance, une durée, une note sont des variables quantitatives.* \
# \- Une variable qui n'est pas quantitative est __qualitative__.  \
# *Une couleur, un diplôme, un prénom sont des variables qualitatives.* \
# \- Une variable quantitative est dite __discrète__ si elle ne prend que des valeurs isolées. \
# *Un âge, une note arrondie au demi−point sont des variables discrètes.* \
# \- Une variable quantitative est dite __continue__ si elle peut prendre toutes les valeurs comprises entre 2 nombres. \
# *La distance entre le domicile et le collège est une variable quantitative continue.*
#
# -------------

# %%
house_pricing = pd.read_csv("dataset/house_pricing.csv")
print(house_pricing.shape)
house_pricing.head()
# Out:
# (1460, 81)
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# Dans ce dataset on retrouve 81 variables.
# Elles sont soit des strings, soit des int.
# La plupart des variables sont qualitative, certaines (SalePrice) sont quantitatives (et discrètes)

# %% [markdown]
# #### 3) En créant un nuage de points, regardez comment se comporte la colonne LotArea par rapport au SalesPrices

# %%
x = house_pricing.loc[:, 'LotArea']
y = house_pricing.loc[:, 'SalePrice']

plt.scatter(x,y)

plt.title('Nuage de points')
plt.xlabel('Lot Area')
plt.ylabel('Sale Price')

# plt.savefig('exercice1.png')
plt.show()

# %% [markdown]
# #### 4) Affinez votre visualisation en ne gardant uniquement les maisons qui ont un LotArea inférieur à 20 000 pieds carrés et un prix inférieur à 500 000$

# %%
lotArea_lesser_than_20_000 = house_pricing['LotArea'] < 20000
datas = house_pricing[lotArea_lesser_than_20_000]
print('lotArea_lesser_than_20_000 :', datas.loc[:,'LotArea'].describe(), '\n')

salePrice_lesser_than_500_000 = datas['SalePrice'] < 500000
datas = datas[salePrice_lesser_than_500_000]
print('salePrice_lesser_than_500_000 :', datas.loc[:,'SalePrice'].describe())

datas
# Out:
# lotArea_lesser_than_20_000 : count     1407.000000
# mean      9354.925373
# std       3327.200183
# min       1300.000000
# 25%       7447.500000
# 50%       9317.000000
# 75%      11281.000000
# max      19900.000000
# Name: LotArea, dtype: float64
#
# salePrice_lesser_than_500_000 : count      1401.000000
# mean     176398.176303
# std       70653.060739
# min       34900.000000
# 25%      129000.000000
# 50%      160000.000000
# 75%      208900.000000
# max      485000.000000
# Name: SalePrice, dtype: float64
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...

# %% [markdown]
# #### 5) En créant un nuage de points, regardez la relation entre le LotFrontage et le LotArea

# %%
x = datas.loc[ : , 'LotArea' ]
y = datas.loc[ : , 'LotFrontage' ]

plt.scatter(x,y)

plt.title('Nuage de points')
plt.xlabel('Lot Area')
plt.ylabel('Lot Frontage')

# plt.savefig('exercice1.png')
plt.show()

# %% [markdown]
# #### 6) De la même manière, affinez votre visualisation en ne gardant uniquement les maisons qui ont un LotFrontage inférieur à 200 pieds carrés et un LotArea inférieur à 100 000 pieds carré

# %%
lotFrontage_lesser_than_200 = datas['LotFrontage'] <= 200
datas = datas[lotFrontage_lesser_than_200]
print('lotFrontage_lesser_than_200 :', datas.loc[:,'LotFrontage'].describe(), '\n')

lotArea_lesser_than_100_000 = datas['LotArea'] <= 100000
datas = datas[lotArea_lesser_than_100_000]
print('lotArea_lesser_than_100_000 :', datas.loc[:,'LotArea'].describe())

datas
# Out:
# lotFrontage_lesser_than_200 : count    1162.000000
# mean       68.934596
# std        21.193929
# min        21.000000
# 25%        59.000000
# 50%        69.000000
# 75%        80.000000
# max       182.000000
# Name: LotFrontage, dtype: float64
#
# lotArea_lesser_than_100_000 : count     1162.000000
# mean      9156.511188
# std       3209.681975
# min       1300.000000
# 25%       7304.000000
# 50%       9138.500000
# 75%      10979.250000
# max      19378.000000
# Name: LotArea, dtype: float64
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...

# %%
x = datas.loc[ : , 'LotArea' ]
y = datas.loc[ : , 'LotFrontage' ]

plt.scatter(x,y)

plt.title('Nuage de points')
plt.xlabel('Lot Area')
plt.ylabel('Lot Frontage')

# plt.savefig('exercice1.png')
plt.show()

# %% [markdown]
# ## Visualisation de relations continues
# Pour cette partie, nous utiliserons le dataset suivant : sales_predictions.csv que vous pouvez
# trouver dans le dossier Data Sources.

# %% [markdown]
# #### 1) Importez les librairies qu’il vous faut

# %% [markdown]
# #### 2) En utilisant relplot(), construisez un graphique qui va vous permettre de voir l’évolution des prix par rapport au temps. Que pouvez vous voir ?

# %% [markdown]
# #### 3) Corrigeons le problème de visualisation, en utilisant la fonction .sample() de Pandas, prenez un échantillons de 50 éléments dans votre dataset

# %% [markdown]
# #### 4) Retentez de faire votre visualisation, créez une figure de taille (20,6). Que voyez vous ?

# %% [markdown]
# 5) En utilisant la fonction pd.to_datetime(), convertissez votre colonne date en datetime

# %% [markdown]
# 6) Retentez une dernière fois votre visualisation.
